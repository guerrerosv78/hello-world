# %% [markdown]
# # Ejercicios de optimización escalar

# %% [markdown]
# **Para la siguientes funciones encuentre los puntos críticos, grafique y diga si éste se trata de un máximo o mínimo, local o global.**

# %% [markdown]
# $f(x)=1260+117x-9x^2$

# %%
import sympy as sp
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

def f(x):
    return (1260 + 117*x - 9*x**2)

sp.var("x")
f(x)
# Out:
# -9*x**2 + 117*x + 1260

# %%
df = sp.diff(f(x),x)
df
# Out:
# 117 - 18*x

# %%
sp.solve(df,x)
# Out:
# [13/2]

# %%
ddf = sp.diff(df, x)
ddf
# Out:
# -18

# %%
# %matplotlib inline 

def df(x) :
    return 1260 + 117*x - 9*x**2
 

xn = np.linspace(0,7,1000)
yn = f(xn)


plt.figure()
plt.plot(xn, yn)
#plt.plot(xn, dyn)
plt.grid()

# %% [markdown]
# El punto crítico es 13/2 y un máximo global.

# %% [markdown]
# $f(x)=5+x+\frac{4}{x}$, para $x>0$

# %%
def f(x):
    return (5 + 1*x + 4/x)
f(x)
# Out:
# x + 5 + 4/x

# %%
df = sp.diff(f(x),x)
df
# Out:
# 1 - 4/x**2

# %%
sp.solve(df,x)
# Out:
# [-2, 2]

# %%
# %matplotlib inline 

def df(x) :
    return 5 + 1*x + 4/x
 

xn = np.linspace (0.1, 10,1000)
yn = f(xn)


plt.figure()
plt.plot(xn, yn)
#plt.plot(xn, dyn)
plt.grid()

# %% [markdown]
# El punto crítico es 2 y es un mínimo global

# %% [markdown]
# $f(x)=6-2x+\sqrt{18-2x^2}$, para $-3\leq x\leq 3$

# %%
sp.var("x")

def f(x):
    return 6 - 2*x + sp.sqrt(18-2*x**2)
f(x)
# Out:
# -2*x + sqrt(18 - 2*x**2) + 6

# %%
df = sp.diff(f(x),x)
df
# Out:
# -2*x/sqrt(18 - 2*x**2) - 2

# %%
sp.solve(df,x)
# Out:
# [-sqrt(6)]

# %%
# %matplotlib inline 

def f(x) :
    return 6 - 2*x + np.sqrt(18-2*x**2)
 

xn = np.linspace (-3, 3, 1000)
yn = f(xn)


plt.figure()
plt.plot(xn, yn)
#plt.plot(xn, dyn)
plt.grid()

# %%
El punto crítico es - raíz de 6 y es un máximo local.

# %% [markdown]
# $f(x)=\frac{1}{4}x^4+\frac{1}{3}x^3-x^2$ en el intervalo $[-3,1.7]$

# %%
def f(x):
    return (1/4*x**4 + 1/3*x**3 - x**2)
f(x)
# Out:
# 0.25*x**4 + 0.333333333333333*x**3 - x**2

# %%
df = sp.diff(f(x),x)
df
# Out:
# 1.0*x**3 + 1.0*x**2 - 2*x

# %%
sp.solve(df,x)
# Out:
# [-2.00000000000000, 0.0, 1.00000000000000]

# %%
# %matplotlib inline 

def f(x) :
    return 1/4*x**4 + 1/3*x**3 - x**2
 

xn = np.linspace (-3, 1.7, 1000)
yn = f(xn)


plt.figure()
plt.plot(xn, yn)
#plt.plot(xn, dyn)
plt.grid()

# %%
Los puntos críticos son -2, 0 y 1, y son un mínimo local, un máxico global y un mínimo global.

# %% [markdown]
# ---
# **Resuelva los siguientes problemas usando la librería `SymPy`. Use celdas en `Markdown` para explicar su procedimiento.**

# %% [markdown]
# El perímetro de un triángulo isósceles es de $10 cm$. ¿Cuánto deben medir sus lados para que el volumen del cuerpo generado por la rotación del triángulo en torno a su base sea el mayor posible? (Volumen de un cono $= \frac{1}{3}\pi r^2 h$, donde $r$ es el radio de la base y $h$ la altura del cono).

# %%
import sympy as sp
import numpy as np

sp.var ("x")
sp.var ("y")
sp.var ("h")
# Out:
# h

# %%
def f(x):
    return (1/3*sp.pi*(y/2)**2*h)
f(x)
# Out:
# 0.0833333333333333*pi*h*y**2

# %%
def f(y):
    return (2*x + y -10)
f(y)
# Out:
# 2*x + y - 10

# %%
pc = sp.solve(f(y),x)[0]
pc
# Out:
# 5 - y/2

# %%
altura = sp.sqrt((x**2)-(y/2)**2)

# %%
altura
# Out:
# sqrt(x**2 - y**2/4)

# %%
area = altura.subs(x, pc) 
area
# Out:
# sqrt(-y**2/4 + (5 - y/2)**2)

# %%
def f(x):
    return (1/3*sp.pi*(y/2)**2*h)

# %%
volumen = f(x).subs(h, area)
volumen
# Out:
# 0.0833333333333333*pi*y**2*sqrt(-y**2/4 + (5 - y/2)**2)

# %%
volumen_x = sp.diff(volumen, y)
volumen_x
# Out:
# -0.208333333333333*pi*y**2/sqrt(-y**2/4 + (5 - y/2)**2) + 0.166666666666667*pi*y*sqrt(-y**2/4 + (5 - y/2)**2)

# %%
y_num = sp.solve(volumen_x, y)[1]
y_num
# Out:
# 4.00000000000000

# %% [markdown]
# El valor de "y" sería de 4

# %%
x_num = pc.subs(y, y_num[1])
x_num
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_912\880732438.py in <module>
# ----> 1 x_num = pc.subs(y, y_num[1])
#       2 x_num
#
# TypeError: 'Float' object is not subscriptable

# %% [markdown]
# Para maximizar el volumen del cono

# %% [markdown]
# Disponemos de una barra de aluminio de 6 metros para construir una portería de fútbol. Si queremos que el área de la portería sea máxima, ¿cuánto deben medir los postes y el travesaño?

# %%
import sympy as sp
import numpy as np

sp.var ("x")
sp.var ("y")
# Out:
# y

# %%
def f(x):
    return (2*x + y -6)
f(x)
# Out:
# 2*x + y - 6

# %%
pc = sp.solve(f(x),x)[0]
pc
# Out:
# 3 - y/2

# %%
area = x*y
area_y = area.subs(x, pc) 
area_y
# Out:
# y*(3 - y/2)

# %%
darea_y = sp.diff(area_y, y)
darea_y
# Out:
# 3 - y

# %%
y_num = sp.solve(darea_y, y)[0]
y_num
# Out:
# 3

# %%
sp.diff(darea_y, y).subs(y, y_num) #Como es negativo no me sirve; es un mínimo.
# Out:
# -1

# %%
(pc.subs(y, y_num))
# Out:
# 3/2

# %% [markdown]
# Los postes deben de medir 1.5 y el travesaño 3
