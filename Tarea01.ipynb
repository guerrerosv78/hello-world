# %% [markdown]
# # Tarea 01
# ## Sofía Vázquez Guerrero
# *Ingeniería Financiera, tercer semestre*
#
# **739167**

# %% [markdown]
# ### Presentación

# %% [markdown]
# Mi nombre es Sofía Vázquez Guerrero, tengo 20 años y estudio Ingeniería Financiera. Algunas materias que tengo son:
# 1. Cálculo diferencial
# 2. Programación
# 3. Bolsa de Valores
# 4. Derecho

# %% [markdown]
# Llamas (2020) afirma que: "La Ingeniería Financiera es la disciplina que aplica procesos para la innovación, invención, desarrollo y mejora de técnicas orientadas a las finanzas" (p.1).
#
# Algunas características son:
# - Se basa en herramientas de matemática aplicada, informática, estadística y teoría económica.
# - Se puede aplicar a muchas clases de activos diferentes, incluidas acciones, renta fija.
# - Emplea modelos matemáticos, teoría financiera y habilidades de programación informática para tomar decisiones de fijación de precios, cobertura, negociación y gestión de cartera.

# %% [markdown]
# ![bolsa.jfif](attachment:bolsa.jfif)

# %% [markdown]
# En mi carrera se utilizan distintas ecuaciones, una de las más comunes es $y=mx+b$

# %% [markdown]
# **Referencias:**
#
#
# Llamas, J. (2022, 24 noviembre). Ingeniería financiera. Economipedia. https://economipedia.com/definiciones/ingenieria-financiera.html
